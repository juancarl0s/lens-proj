# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create 2 functions:
# 1. `add_euclidian_distances(df)`: adds columns to passed dataframe for:
#     - Movement between the current and last trial in mm
#     - Distance between the current position in the trial and the center of reference space
# 2. `get_movement_summary(df, threshold=1.5)`: returns a new dataframe with 3 columns for each subject:
#     - `max_between_trial_movement_dS_dL_dP`: maximun between trial movement recorded
#     - `max_trial_movement_from_origin_dS_dL_dP`: maximm distance recorded from the center of reference space
#     - `between_trial_movement_over_{threshold}`: number of instances of between trial movements that exceed the threshold specified
#
# Notes (from [afni's `3dvolreg` docs](https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dvolreg.html)) :
#   - roll  = rotation about the I-S axis }
#   - pitch = rotation about the R-L axis } degrees CCW
#   - yaw   = rotation about the A-P axis }
#   - dS  = displacement in the Superior direction  }
#   - dL  = displacement in the Left direction      } mm
#   - dP  = displacement in the Posterior direction }

# %%
def add_euclidian_distances(df):
    df['diff_last_dS'] = df['dS'] - df['dS'].shift(1)
    df['diff_last_dL'] = df['dL'] - df['dL'].shift(1)
    df['diff_last_dP'] = df['dP'] - df['dP'].shift(1)
    df.fillna(0)
    df['between_last_trial_movement_dS_dL_dP'] = np.sqrt(df['diff_last_dS']**2 + df['diff_last_dL']**2 + df['diff_last_dP']**2)
    df['trial_movement_from_origin_dS_dL_dP'] = np.sqrt(df['dS']**2 + df['dL']**2 + df['dP']**2)
    return df
    
def get_movement_summary(df, threshold=1.5):
    max_movements = (
        df[['between_last_trial_movement_dS_dL_dP','trial_movement_from_origin_dS_dL_dP']]
            .max(axis=0)
            .copy()
            .rename({
                "between_last_trial_movement_dS_dL_dP":"max_between_trial_movement_dS_dL_dP",
                "trial_movement_from_origin_dS_dL_dP":"max_trial_movement_from_origin_dS_dL_dP",
            })
    )
    above_thrs_move = (
        (df[['between_last_trial_movement_dS_dL_dP']]>1.5)
            .sum()
            .rename({
                "between_last_trial_movements_dS_dL_dP":"between_trial_movement_over_"+str(threshold)
            })
    )
            
    summary = pd.concat([max_movements,above_thrs_move])
    
    return summary

# %% [markdown]
# Create a list of subject labels for all the subjects in the dataset

# %%
subjs = ["sub-"+str(i) if i>9 else "sub-0"+str(i) for i in range(1,30)]
subjs
# Out:
# ['sub-01',
#  'sub-02',
#  'sub-03',
#  'sub-04',
#  'sub-05',
#  'sub-06',
#  'sub-07',
#  'sub-08',
#  'sub-09',
#  'sub-10',
#  'sub-11',
#  'sub-12',
#  'sub-13',
#  'sub-14',
#  'sub-15',
#  'sub-16',
#  'sub-17',
#  'sub-18',
#  'sub-19',
#  'sub-20',
#  'sub-21',
#  'sub-22',
#  'sub-23',
#  'sub-24',
#  'sub-25',
#  'sub-26',
#  'sub-27',
#  'sub-28',
#  'sub-29']

# %% [markdown]
# Load each of the subjects movement file into a dictionary keyed by subject label (ie: `"subj-01":pd.DataFrame`}

# %%
subj_dfs = {sub:pd.read_csv(
                        "./data/afni_head_motion/"+sub+"_results/dfile_rall.1D",
                        names=["roll","pitch","yaw", "dS","dL","dP"],
                        header=None,
                        sep="\s+")
            for sub in subjs}
subj_dfs["sub-01"]
# Out:
#         roll   pitch     yaw      dS      dL      dP
# 0    -0.0927  0.2573 -0.0945 -0.1759 -0.0305 -0.0444
# 1    -0.0040 -0.0484  0.0129 -0.0070 -0.0101 -0.0045
# 2    -0.0000 -0.0000  0.0000 -0.0000  0.0000  0.0000
# 3    -0.0050  0.0185 -0.0055 -0.0114 -0.0095  0.0027
# 4    -0.0133  0.0748 -0.0097 -0.0173 -0.0245  0.0058
# ...      ...     ...     ...     ...     ...     ...
# 1771  0.3846 -1.6100  0.1905  4.6896  0.0914 -0.5238
# 1772  0.3122 -0.9665  0.2230  4.8031  0.2233 -0.5875
# 1773  0.3234 -0.7923  0.2275  4.8280  0.2539 -0.6520
# 1774  0.3230 -1.0059  0.2517  4.2369  0.1181 -0.6951
# 1775  0.3747 -1.3114  0.3293  3.7768  0.0930 -0.7707
#
# [1776 rows x 6 columns]

# %% [markdown]
# Create new dictionary `subj_dfs` where the keys are the subject labels and the values are corresponding DataFrames with the new distances columns added (using `add_euclidian_distances` function)

# %%
subj_dfs = {k:add_euclidian_distances(v) for k,v in subj_dfs.items()}

# %% [markdown]
# Create new dictionary `subj_summaries` where the keys are the subject labels and the values are corresponding DataFrames with the distance summaries (using the `get_movement_summary` function)

# %%
subj_summaries = {k:get_movement_summary(v) for k,v in subj_dfs.items()}
subj_summaries
# Out:
# {'sub-01': max_between_trial_movement_dS_dL_dP        3.278866
#  max_trial_movement_from_origin_dS_dL_dP    5.494173
#  between_last_trial_movement_dS_dL_dP       2.000000
#  dtype: float64,
#  'sub-02': max_between_trial_movement_dS_dL_dP        0.364302
#  max_trial_movement_from_origin_dS_dL_dP    1.644770
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-03': max_between_trial_movement_dS_dL_dP        0.456543
#  max_trial_movement_from_origin_dS_dL_dP    1.159871
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-04': max_between_trial_movement_dS_dL_dP        0.244903
#  max_trial_movement_from_origin_dS_dL_dP    2.012193
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-05': max_between_trial_movement_dS_dL_dP        3.555287
#  max_trial_movement_from_origin_dS_dL_dP    4.073179
#  between_last_trial_movement_dS_dL_dP       2.000000
#  dtype: float64,
#  'sub-06': max_between_trial_movement_dS_dL_dP        1.257643
#  max_trial_movement_from_origin_dS_dL_dP    3.220474
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-07': max_between_trial_movement_dS_dL_dP        1.330638
#  max_trial_movement_from_origin_dS_dL_dP    1.702199
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-08': max_between_trial_movement_dS_dL_dP        2.002354
#  max_trial_movement_from_origin_dS_dL_dP    1.811183
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-09': max_between_trial_movement_dS_dL_dP        0.648505
#  max_trial_movement_from_origin_dS_dL_dP    5.408551
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-10': max_between_trial_movement_dS_dL_dP        3.136012
#  max_trial_movement_from_origin_dS_dL_dP    5.709135
#  between_last_trial_movement_dS_dL_dP       4.000000
#  dtype: float64,
#  'sub-11': max_between_trial_movement_dS_dL_dP        1.599647
#  max_trial_movement_from_origin_dS_dL_dP    1.970085
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-12': max_between_trial_movement_dS_dL_dP        2.168424
#  max_trial_movement_from_origin_dS_dL_dP    2.830562
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-13': max_between_trial_movement_dS_dL_dP        0.314771
#  max_trial_movement_from_origin_dS_dL_dP    2.857321
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-14': max_between_trial_movement_dS_dL_dP        2.300852
#  max_trial_movement_from_origin_dS_dL_dP    4.649596
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-15': max_between_trial_movement_dS_dL_dP        0.707306
#  max_trial_movement_from_origin_dS_dL_dP    3.321673
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-16': max_between_trial_movement_dS_dL_dP        0.309990
#  max_trial_movement_from_origin_dS_dL_dP    2.366739
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-17': max_between_trial_movement_dS_dL_dP        2.358894
#  max_trial_movement_from_origin_dS_dL_dP    2.319799
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-18': max_between_trial_movement_dS_dL_dP        0.900441
#  max_trial_movement_from_origin_dS_dL_dP    1.486896
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-19': max_between_trial_movement_dS_dL_dP        0.736916
#  max_trial_movement_from_origin_dS_dL_dP    2.360927
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-20': max_between_trial_movement_dS_dL_dP        0.804308
#  max_trial_movement_from_origin_dS_dL_dP    2.356611
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-21': max_between_trial_movement_dS_dL_dP        0.505248
#  max_trial_movement_from_origin_dS_dL_dP    2.200255
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-22': max_between_trial_movement_dS_dL_dP        0.674373
#  max_trial_movement_from_origin_dS_dL_dP    1.233267
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-23': max_between_trial_movement_dS_dL_dP        1.777113
#  max_trial_movement_from_origin_dS_dL_dP    2.671047
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-24': max_between_trial_movement_dS_dL_dP        1.497722
#  max_trial_movement_from_origin_dS_dL_dP    3.708409
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-25': max_between_trial_movement_dS_dL_dP        0.402049
#  max_trial_movement_from_origin_dS_dL_dP    2.806247
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-26': max_between_trial_movement_dS_dL_dP        0.794137
#  max_trial_movement_from_origin_dS_dL_dP    2.187773
#  between_last_trial_movement_dS_dL_dP       0.000000
#  dtype: float64,
#  'sub-27': max_between_trial_movement_dS_dL_dP        4.658260
#  max_trial_movement_from_origin_dS_dL_dP    5.254098
#  between_last_trial_movement_dS_dL_dP       6.000000
#  dtype: float64,
#  'sub-28': max_between_trial_movement_dS_dL_dP        2.454509
#  max_trial_movement_from_origin_dS_dL_dP    4.114023
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64,
#  'sub-29': max_between_trial_movement_dS_dL_dP        2.680638
#  max_trial_movement_from_origin_dS_dL_dP    3.717306
#  between_last_trial_movement_dS_dL_dP       1.000000
#  dtype: float64}

# %%
summaries_df = pd.DataFrame(subj_summaries)
summaries_df.T
# Out:
#         max_between_trial_movement_dS_dL_dP  \
# sub-01                             3.278866
# sub-02                             0.364302
# sub-03                             0.456543
# sub-04                             0.244903
# sub-05                             3.555287
# sub-06                             1.257643
# sub-07                             1.330638
# sub-08                             2.002354
# sub-09                             0.648505
# sub-10                             3.136012
# sub-11                             1.599647
# sub-12                             2.168424
# sub-13                             0.314771
# sub-14                             2.300852
# sub-15                             0.707306
# sub-16                             0.309990
# sub-17                             2.358894
# sub-18                             0.900441
# sub-19                             0.736916
# sub-20                             0.804308
# sub-21                             0.505248
# sub-22                             0.674373
# sub-23                             1.777113
# sub-24                             1.497722
# sub-25                             0.402049
# sub-26                             0.794137
# sub-27                             4.658260
# sub-28                             2.454509
# sub-29                             2.680638
#
#         max_trial_movement_from_origin_dS_dL_dP  \
# sub-01                                 5.494173
# sub-02                                 1.644770
# sub-03                                 1.159871
# sub-04                                 2.012193
# sub-05                                 4.073179
# sub-06                                 3.220474
# sub-07                                 1.702199
# sub-08                                 1.811183
# sub-09                                 5.408551
# sub-10                                 5.709135
# sub-11                                 1.970085
# sub-12                                 2.830562
# sub-13                                 2.857321
# sub-14                                 4.649596
# sub-15                                 3.321673
# sub-16                                 2.366739
# sub-17                                 2.319799
# sub-18                                 1.486896
# sub-19                                 2.360927
# sub-20                                 2.356611
# sub-21                                 2.200255
# sub-22                                 1.233267
# sub-23                                 2.671047
# sub-24                                 3.708409
# sub-25                                 2.806247
# sub-26                                 2.187773
# sub-27                                 5.254098
# sub-28                                 4.114023
# sub-29                                 3.717306
#
#         between_last_trial_movement_dS_dL_dP
# sub-01                                   2.0
# sub-02                                   0.0
# sub-03                                   0.0
# sub-04                                   0.0
# sub-05                                   2.0
# sub-06                                   0.0
# sub-07                                   0.0
# sub-08                                   1.0
# sub-09                                   0.0
# sub-10                                   4.0
# sub-11                                   1.0
# sub-12                                   1.0
# sub-13                                   0.0
# sub-14                                   1.0
# sub-15                                   0.0
# sub-16                                   0.0
# sub-17                                   1.0
# sub-18                                   0.0
# sub-19                                   0.0
# sub-20                                   0.0
# sub-21                                   0.0
# sub-22                                   0.0
# sub-23                                   1.0
# sub-24                                   0.0
# sub-25                                   0.0
# sub-26                                   0.0
# sub-27                                   6.0
# sub-28                                   1.0
# sub-29                                   1.0

# %%
(summaries_df.T).to_csv("data/movement_summaries.csv", header=True, index=True)
